# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division 
from scipy import *                  
from pylab import * 
import os

UA=149597870700
jour=3600*24
annee=365*3600*24
k=2*np.pi

#Rayons des orbites des planètes
Rmercure=0.38709893*UA
Rvenus=0.723332*UA
Rterre=1*UA
Rmars=1.52366231*UA
Rjupiter=5.20336301*UA
Rsaturne=9.554909*UA
Ruranus=19.189165*UA
Rneptune=30.10366151*UA
Rsoleil=696342000

#Périodes des planètes
Tmercure=87.96934*jour
Tvenus=224.701*jour
Tterre=1*annee
Tmars=1.8808*annee
Tjupiter=11.862*annee
Tsaturne=10757.7365*jour
Turanus=84.016846*annee
Tneptune=60224.9036*jour
Tsoleil=27.28*jour

Lplanetes=[(Rmercure,Tmercure),(Rvenus,Tvenus),(Rterre,Tterre),(Rmars,Tmars),(Rjupiter,Tjupiter),
   (Rsaturne,Tsaturne),(Ruranus,Turanus),(Rneptune,Tneptune)]

#angle continu
def theta(T):
    return k*np.linspace(0, T, 1000)/T

#Listes des coordonnées des planètes
X=[R*np.cos(theta(T)) for (R,T) in Lplanetes]
Y=[R*np.sin(theta(T)) for (R,T) in Lplanetes]
#Couleurs des orbites
couleurs=['grey','green','blue','red','orange','black','green','blue']
noms=['Mercure','Vénus','Terre','Mars','Jupiter','Saturne','Uranus','Neptune']

#Coordonnées des planètes
#Soleil
xsol=Rsoleil*np.cos(theta(Tsoleil))
ysol=Rsoleil*np.sin(theta(Tsoleil))
#Mercure
xme=X[0]
yme=Y[0]
#Vénus
xv=X[1]
yv=Y[1]
#Terre
xt=X[2]
yt=Y[2]
#Mars
xma=X[3]
yma=Y[3]
#Jupiter
xj=X[4]
yj=Y[4]
#Saturne
xsa=X[5]
ysa=Y[5]
#Uranus
xu=X[6]
yu=Y[6]
#Neptune
xn=X[7]
yn=Y[7]

#Tracé des orbites
for (x,y,c,n) in zip(X,Y,couleurs,noms):
    plt.plot(x,y,color=c,linewidth=1,linestyle='-',label=n)
plt.plot(xsol,ysol,color='orange',linewidth=5,linestyle='-')
plt.axis("equal")
plt.title("Orbites des planètes autour du Soleil")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
#mvt des planètes dans le référentiel géocentrique
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

#angle continu
def thetageo(T):
    return k*np.linspace(0, Tneptune, 1000)/T

#Listes des coordonnées des planètes dans le référentiel géocentrique
Xgeo=[R*np.cos(thetageo(T)) for (R,T) in Lplanetes]
Ygeo=[R*np.sin(thetageo(T)) for (R,T) in Lplanetes]
xtgeo=Xgeo[2]
ytgeo=Ygeo[2]

#Tracé des trajectoires dans le référentiel géocentrique
for (x,y,c,n) in zip(Xgeo,Ygeo,couleurs,noms):
    plt.plot(x-xtgeo,y-ytgeo,color=c,linewidth=1,linestyle='-',label=n)
plt.axis("equal")
plt.title("Trajectoires des planètes dans le référentiel géocentrique")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
#systeme solaire interne
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

#Listes des coordonnées des planètes du système solaire interne
#(Mercure, Vénus, Terre, Mars, Jupiter)
Lint=[(Rmercure,Tmercure),(Rvenus,Tvenus),(Rterre,Tterre),(Rmars,Tmars),(Rjupiter,Tjupiter)]
Xint=[R*np.cos(theta(T)) for (R,T) in Lint]
Yint=[R*np.sin(theta(T)) for (R,T) in Lint]
couleursint=['grey','green','blue','red','orange']
nomsint=['Mercure','Vénus','Terre','Mars','Jupiter']

#Tracé des orbites internes
for (x,y,c,n) in zip(Xint,Yint,couleursint,nomsint):
    plt.plot(x,y,color=c,linewidth=1,linestyle='-',label=n)
plt.plot(xsol,ysol,color='orange',linewidth=5,linestyle='-')
plt.axis("equal")
plt.title("Orbites des planètes du système solaire interne")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
#mvt des planètes dans le référentiel géocentrique dans le systeme solaire interne
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

#angle continu
def thetageoint(T):
    return k*np.linspace(0, Tjupiter, 1000)/T

#Listes des coordonnées des planètes  du système solaire interne dans le référentiel géocentrique
Xgeoint=[R*np.cos(thetageoint(T)) for (R,T) in Lplanetes[:5]]
Ygeoint=[R*np.sin(thetageoint(T)) for (R,T) in Lplanetes[:5]]
xtgeoint=Xgeoint[2]
ytgeoint=Ygeoint[2]

#Tracé des trajectoires de Mercure, Vénus, Mars, Jupiter dans le référentiel géocentrique
for (x,y,c,n) in zip(Xgeoint,Ygeoint,couleurs,noms):
    plt.plot(x-xtgeoint,y-ytgeoint,color=c,linewidth=1,linestyle='-',label=n)
plt.axis("equal")
plt.title("Trajectoires du système solaire interne dans le référentiel géocentrique")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
#Animation Terre-Mars
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division 
from scipy import *                  
from pylab import * 
import os

UA=149597870700
jour=3600*24
annee=365*3600*24
k=2*np.pi

Rterre=1*UA
Rmars=1.52366231*UA
Rsoleil=696342000

Tterre=1*annee
Tmars=1.8808*annee
Tsoleil=27.28*jour


#initialisation 
tini = 0 
tfin = 2*annee 
Npas = 2*365

#angle discret
def alpha(t,T):
    return k*t/T

#Positions Successives 
def Positionsterre(t): 
    x = Rterre*np.cos(alpha(t,Tterre))
    y = Rterre*np.sin(alpha(t,Tterre))
    return [x, y]

def Positionsmars(t):
    x = Rmars*np.cos(alpha(t,Tmars))
    y = Rmars*np.sin(alpha(t,Tmars))
    return [x, y]
 
# Construction d'une série d'images et de leur assemblage dans une animation 
for k in range(Npas): 
    t = tini + 20*jour
    #Orbite de la Terre
    plt.plot(xt,yt,color='blue',linewidth=1,linestyle='-.')
    #Orbite de Mars
    plt.plot(xma,yma,color='red',linewidth=1,linestyle='-.')
    #Soleil
    plt.plot(xsol,ysol,color='orange',linewidth=5,linestyle='-')
    #Positions de la Terre
    plt.plot(Positionsterre(t)[0], Positionsterre(t)[1], 'o', color='blue')
    #Positions de Mars
    plt.plot(Positionsmars(t)[0], Positionsmars(t)[1], 'o', color='red')
    plt.axis('equal') 
    savefig('fichierTemp'+str('%02d' %k)+'.pdf') 
    clf()
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0531b815dbeb> in <module>()
#      51     plt.axis('equal')
#      52     filename = 'fichierTemp'+str('%02d' %k)+'.pdf'
# ---> 53     savefig(filename)
#      54     clf()
#
# C:\Python34\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# C:\Python34\lib\site-packages\matplotlib\figure.py in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# C:\Python34\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2209                 orientation=orientation,
#    2210                 bbox_inches_restore=_bbox_inches_restore,
# -> 2211                 **kwargs)
#    2212         finally:
#    2213             if bbox_inches and restore_bbox:
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2483                 RendererPdf(file, image_dpi),
#    2484                 bbox_inches_restore=_bbox_inches_restore)
# -> 2485             self.figure.draw(renderer)
#    2486             renderer.finalize()
#    2487         finally:
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1117
#    1118         for tick in ticks_to_draw:
# -> 1119             tick.draw(renderer)
#    1120
#    1121         # scale up the axis label box to also find the neighbors, not
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\axis.py in draw(self, renderer)
#     244                 self.tick1line.draw(renderer)
#     245             if self.tick2On:
# --> 246                 self.tick2line.draw(renderer)
#     247
#     248         if self.label1On:
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     758                 renderer.draw_markers(gc, marker_path, marker_trans,
#     759                                       subsampled, affine.frozen(),
# --> 760                                       rgbaFace)
#     761
#     762                 alt_marker_path = marker.get_alt_path()
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in draw_markers(self, gc, marker_path, marker_trans, path, trans, rgbFace)
#    1672         if len_marker_path * uses < len_marker_path + uses + 5:
#    1673             RendererBase.draw_markers(self, gc, marker_path, marker_trans,
# -> 1674                                       path, trans, rgbFace)
#    1675             return
#    1676
#
# C:\Python34\lib\site-packages\matplotlib\backend_bases.py in draw_markers(self, gc, marker_path, marker_trans, path, trans, rgbFace)
#     263                                marker_trans +
#     264                                transforms.Affine2D().translate(x, y),
# --> 265                                rgbFace)
#     266
#     267     def draw_path_collection(self, gc, master_transform, paths, all_transforms,
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in draw_path(self, gc, path, transform, rgbFace)
#    1592             path, transform,
#    1593             rgbFace is None and gc.get_hatch_path() is None,
# -> 1594             gc.get_sketch_params())
#    1595         self.file.output(self.gc.paint())
#    1596
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in writePath(self, path, transform, clip, sketch)
#    1408         cmds = self.pathOperations(path, transform, clip, simplify=simplify,
#    1409                                    sketch=sketch)
# -> 1410         self.output(*cmds)
#    1411
#    1412     def reserveObject(self, name=''):
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in output(self, *data)
#     565
#     566     def output(self, *data):
# --> 567         self.write(fill(list(map(pdfRepr, data))))
#     568         self.write(b'\n')
#     569
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in write(self, data)
#     562             self.fh.write(data)
#     563         else:
# --> 564             self.currentstream.write(data)
#     565
#     566     def output(self, *data):
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in write(self, data)
#     394             self.file.write(data)
#     395         else:
# --> 396             compressed = self.compressobj.compress(data)
#     397             self.file.write(compressed)
#     398
#
# KeyboardInterrupt:

# %%
#Animation système solaire interne
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division
from scipy import *             
from pylab import *
import os

UA=149597870700
jour=3600*24
annee=365*3600*24
k=2*np.pi

Rmercure=0.38709893*UA
Rvenus=0.723332*UA
Rterre=1*UA
Rmars=1.52366231*UA
Rjupiter=5.20336301*UA
Rsoleil=696342000

Tmercure=87.96934*jour
Tvenus=224.701*jour
Tterre=1*annee
Tmars=1.8808*annee
Tjupiter=11.862*annee
Tsoleil=27.28*jour

#Coordonnées des planètes du système solaire interne
#Mercure
xme=Xint[0]
yme=Yint[0]
#Vénus
xv=Xint[1]
yv=Yint[1]
#Terre
xt=Xint[2]
yt=Yint[2]
#Mars
xma=Xint[3]
yma=Yint[3]
#Jupiter
xj=Xint[4]
yj=Yint[4]

#initialisation 
tini = 0 
tfin = 2*annee 
Npas = 2*365

def alpha(t,T):
    return k*t/T

#Positions Successives 
def Positionsterre(t): 
    x = Rterre*np.cos(alpha(t,Tterre))
    y = Rterre*np.sin(alpha(t,Tterre))
    return [x, y]

def Positionsmars(t):
    x = Rmars*np.cos(alpha(t,Tmars))
    y = Rmars*np.sin(alpha(t,Tmars))
    return [x, y]

def Positionsmercure(t):
    x = Rmercure*np.cos(alpha(t,Tmercure))
    y = Rmercure*np.sin(alpha(t,Tmercure))
    return [x, y]

def Positionsvenus(t):
    x = Rvenus*np.cos(alpha(t,Tvenus))
    y = Rvenus*np.sin(alpha(t,Tvenus))
    return [x, y]

def Positionsjupiter(t):
    x = Rjupiter*np.cos(alpha(t,Tjupiter))
    y = Rjupiter*np.sin(alpha(t,Tjupiter))
    return [x, y]
 
# Construction d'une série d'images et de leur assemblage dans une animation 
for k in range(Npas): 
    t = tini + 20*jour 
    #Orbite de Mercure
    plt.plot(xme,yme,color='grey',linewidth=1,linestyle='-.')
    #Orbite de Vénus
    plt.plot(xv,yv,color='green',linewidth=1,linestyle='-.')
    #Orbite de la Terre
    plt.plot(xt,yt,color='blue',linewidth=1,linestyle='-.')
    #Orbite de Mars
    plt.plot(xma,yma,color='red',linewidth=1,linestyle='-.')
    #Orbite de Jupiter
    plt.plot(xj,yj,color='orange',linewidth=1,linestyle='-.')
    #Soleil
    plt.plot(xsol,ysol,color='orange',linewidth=5,linestyle='-')
    #Positions de Mercure
    plt.plot(Positionsmercure(t)[0], Positionsmercure(t)[1], 'o', color='grey')
    #Positions de Vénus
    plt.plot(Positionsvenus(t)[0], Positionsvenus(t)[1], 'o', color='green')
    #Positions de la Terre
    plt.plot(Positionsterre(t)[0], Positionsterre(t)[1], 'o', color='blue')
    #Positions de Mars
    plt.plot(Positionsmars(t)[0], Positionsmars(t)[1], 'o', color='red')
    #Positions de Jupiter
    plt.plot(Positionsjupiter(t)[0], Positionsjupiter(t)[1], 'o', color='orange')
    plt.axis('equal') 
    savefig('fichierTemp'+str('%02d' %k)+'.pdf') 
    clf()
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-eb97d8d659e7> in <module>()
#      87     plt.plot(Positionsjupiter(t)[0], Positionsjupiter(t)[1], 'o', color='orange')
#      88     plt.axis('equal')
# ---> 89     savefig('fichierTemp'+str('%02d' %k)+'.pdf')
#      90     clf()
#
# C:\Python34\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# C:\Python34\lib\site-packages\matplotlib\figure.py in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# C:\Python34\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2209                 orientation=orientation,
#    2210                 bbox_inches_restore=_bbox_inches_restore,
# -> 2211                 **kwargs)
#    2212         finally:
#    2213             if bbox_inches and restore_bbox:
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2483                 RendererPdf(file, image_dpi),
#    2484                 bbox_inches_restore=_bbox_inches_restore)
# -> 2485             self.figure.draw(renderer)
#    2486             renderer.finalize()
#    2487         finally:
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1130         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#    1131         self.offsetText.set_text(self.major.formatter.get_offset())
# -> 1132         self.offsetText.draw(renderer)
#    1133
#    1134         if 0:  # draw the bounding boxes around the text for debug
#
# C:\Python34\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Python34\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     640                 renderer.draw_text(gc, x, y, clean_line,
#     641                                    self._fontproperties, angle,
# --> 642                                    ismath=ismath, mtext=mtext)
#     643
#     644         gc.restore()
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#    2033         use_simple_method, chunks = check_simple_method(s)
#    2034         if use_simple_method:
# -> 2035             return draw_text_simple()
#    2036         else:
#    2037             return draw_text_woven(chunks)
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in draw_text_simple()
#    1961                              self.file.fontName(prop),
#    1962                              fontsize,
# -> 1963                              Op.selectfont)
#    1964             self._setup_textpos(x, y, angle)
#    1965             self.file.output(self.encode_string(s, fonttype), Op.show,
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in output(self, *data)
#     565
#     566     def output(self, *data):
# --> 567         self.write(fill(list(map(pdfRepr, data))))
#     568         self.write(b'\n')
#     569
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in write(self, data)
#     562             self.fh.write(data)
#     563         else:
# --> 564             self.currentstream.write(data)
#     565
#     566     def output(self, *data):
#
# C:\Python34\lib\site-packages\matplotlib\backends\backend_pdf.py in write(self, data)
#     394             self.file.write(data)
#     395         else:
# --> 396             compressed = self.compressobj.compress(data)
#     397             self.file.write(compressed)
#     398
#
# KeyboardInterrupt:
