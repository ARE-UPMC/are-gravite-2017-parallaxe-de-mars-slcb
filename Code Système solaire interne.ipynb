# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division 
from scipy import *                  
from pylab import * 
import os

UA=149597870700
jour=3600*24
annee=365*3600*24
tau=2*np.pi

#Rayons des orbites des planètes
Rmercure=0.38709893*UA
Rvenus=0.723332*UA
Rterre=1*UA
Rmars=1.52366231*UA
Rjupiter=5.20336301*UA
Rsoleil=696342000

#Périodes des planètes
Tmercure=87.96934*jour
Tvenus=224.701*jour
Tterre=1*annee
Tmars=1.8808*annee
Tjupiter=11.862*annee
Tsoleil=27.28*jour


Lplanetes=[(Rmercure,Tmercure),(Rvenus,Tvenus),(Rterre,Tterre),(Rmars,Tmars),(Rjupiter,Tjupiter)]

#Durée de la simulation
TT=Tjupiter
#Pas de temps de la simulation
pas=1*jour

#angle continu
def theta(T):
    return (tau*np.linspace(0, TT, TT/pas)/T)%tau

#Listes des coordonnées des planètes du système solaire interne
#(Mercure, Vénus, Terre, Mars, Jupiter)
Lint=[(Rmercure,Tmercure),(Rvenus,Tvenus),(Rterre,Tterre),(Rmars,Tmars),(Rjupiter,Tjupiter)]
Xint=[R*np.cos(theta(T)) for (R,T) in Lint]
Yint=[R*np.sin(theta(T)) for (R,T) in Lint]
couleursint=['grey','green','blue','red','orange']
nomsint=['Mercure','Vénus','Terre','Mars','Jupiter']

#Tracé des orbites internes
for (x,y,c,n) in zip(Xint,Yint,couleursint,nomsint):
    plt.plot(x,y,color=c,linewidth=1,linestyle='-',label=n)
plt.plot(0,0,'o',color='orange')
plt.axis("equal")
xticks([2*n*UA for n in range(-3,4)],[str(2*n)+' UA' for n in range(-3,4)])
yticks([n*UA for n in range(-6,7)],[str(n)+' UA' for n in range(-6,7)])
plt.title("Orbites des planètes du système solaire interne")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
#mvt des planètes dans le référentiel géocentrique dans le systeme solaire interne
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


#Listes des coordonnées des planètes  du système solaire interne dans le référentiel géocentrique
Xgeoint=[R*np.cos(theta(T)) for (R,T) in Lplanetes[:5]]
Ygeoint=[R*np.sin(theta(T)) for (R,T) in Lplanetes[:5]]
xtgeoint=Xgeoint[2]
ytgeoint=Ygeoint[2]

#Tracé des trajectoires de Mercure, Vénus, Mars, Jupiter dans le référentiel géocentrique
for (x,y,c,n) in zip(Xgeoint,Ygeoint,couleursint,nomsint):
    plt.plot(x-xtgeoint,y-ytgeoint,color=c,linewidth=1,linestyle='-',label=n)
plt.axis("equal")
xticks([2*n*UA for n in range(-3,4)],[str(2*n)+' UA' for n in range(-3,4)])
yticks([n*UA for n in range(-6,7)],[str(n)+' UA' for n in range(-6,7)])
plt.title("Trajectoires du système solaire interne dans le référentiel géocentrique")
legend(loc='upper left')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>
